# %%
from tensorflow import keras
from keras.layers import Dense,Flatten,Input
from keras.models import Sequential
from keras.utils import plot_model,to_categorical
from keras.datasets import mnist

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
(X_train,y_train), (X_test,y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
plt.imshow(X_train[2], cmap = 'gray')

# %%
plt.figure(figsize=(16,16))
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.imshow(X_train[i],cmap = 'gray')
  plt.title(f'{y_train[i]}')
  plt.xticks([])
  plt.yticks([])

# %%
plt.figure(figsize=(16,16))
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.imshow(X_test[i],cmap = 'gray')
  plt.title(f'{y_test[i]}')
  plt.xticks([])
  plt.yticks([])

# %%
sns.countplot(x = y_train)
# Out:
# <Axes: ylabel='count'>

# %%
#Normalize
X_train = X_train / 255
X_test = X_test / 255
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_train = X_train.reshape(-1,X_train[0].size)
X_train.shape
# Out:
# (60000, 784)

# %%
X_test = X_test.reshape(-1,X_test[0].size)
X_test.shape
# Out:
# (10000, 784)

# %%
y_train_new = to_categorical(y_train)

y_train_new.shape
# Out:
# (60000, 10)

# %%
y_test_new = to_categorical(y_test)
y_test_new.shape
# Out:
# (10000, 10)

# %% [markdown]
# <h1>Build Model</h1>

# %%
model = Sequential()
model.add(Input(shape = (784,)))
model.add(Dense(512,activation='relu'))
model.add(Dense(256,activation='relu'))
model.add(Dense(10,activation='softmax'))

# %%
model.compile(loss = 'categorical_crossentropy',optimizer = 'adam', metrics = ['accuracy'])

# %%
model.fit(X_train,y_train_new,epochs = 10,batch_size=10)
# Out:
# Epoch 1/10
# 6000/6000 ━━━━━━━━━━━━━━━━━━━━ 51s 8ms/step - accuracy: 0.9075 - loss: 0.2976
# Epoch 2/10
# 6000/6000 ━━━━━━━━━━━━━━━━━━━━ 83s 8ms/step - accuracy: 0.9707 - loss: 0.0933
# Epoch 3/10
# 6000/6000 ━━━━━━━━━━━━━━━━━━━━ 49s 8ms/step - accuracy: 0.9822 - loss: 0.0581
# Epoch 4/10
# 6000/6000 ━━━━━━━━━━━━━━━━━━━━ 83s 8ms/step - accuracy: 0.9859 - loss: 0.0452
# Epoch 5/10
# 6000/6000 ━━━━━━━━━━━━━━━━━━━━ 50s 8ms/step - accuracy: 0.9878 - loss: 0.0412
# Epoch 6/10
# 6000/6000 ━━━━━━━━━━━━━━━━━━━━ 51s 9ms/step - accuracy: 0.9901 - loss: 0.0333
# Epoch 7/10
# 6000/6000 ━━━━━━━━━━━━━━━━━━━━ 60s 10ms/step - accuracy: 0.9913 - loss: 0.0304
# Epoch 8/10
# 5750/6000 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9909 - loss: 0.0295

# %%
new_image = plt.imread('new-char1.jpg',cmap = 'grey')

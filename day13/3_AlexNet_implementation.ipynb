# %%
from tensorflow import keras
from keras.layers import Dense,Flatten,Input,Conv2D,MaxPool2D,Dropout,BatchNormalization
from keras.models import Sequential
from keras.utils import plot_model,to_categorical
from keras.datasets import cifar10
import cv2
import tensorflow
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
(X_train,y_train), (X_test,y_test) = cifar10.load_data()
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 323s 2us/step

# %% [markdown]
# <h1>Alexnet achritecture</h1>

# %%
model = Sequential()

# Layer 1
model.add(Conv2D(128, kernel_size=(5,5), strides=(1,1), input_shape=(32,32,3), padding='same',activation = 'relu'))

model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
model.add(BatchNormalization())

# Layer 2
model.add(Conv2D(256, kernel_size=(3,3), strides=(1,1), padding='same',activation = 'relu'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
model.add(BatchNormalization())

# Layer 3
model.add(Conv2D(256, kernel_size=(3,3), strides=(1,1), padding='same',activation = 'relu'))


# Layer 4
model.add(Conv2D(256, kernel_size=(1,1), strides=(1,1), padding='same',activation = 'relu'))
model.add(BatchNormalization())

# Layer 5
model.add(Conv2D(256, kernel_size=(1,1), strides=(1,1), padding='same',activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

# Flatten
model.add(Flatten())

# Fully Connected Layer 1
model.add(Dense(1024,activation = 'relu'))
model.add(Dropout(0.5))

# Fully Connected Layer 2
model.add(Dense(512,activation = 'relu'))
model.add(Dropout(0.5))

# Output Layer
model.add(Dense(10,activation = 'softmax'))
# Out:
# C:\Users\dai\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    loss = 'sparse_categorical_crossentropy',
    optimizer = 'adam',
    metrics = ['accuracy']
)

# %%
history = model.fit(X_train,y_train, epochs = 30,validation_data=(X_test,y_test))
# Out:
# Epoch 1/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 238s 149ms/step - accuracy: 0.3657 - loss: 1.8384 - val_accuracy: 0.4593 - val_loss: 1.4677
# Epoch 2/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 234s 149ms/step - accuracy: 0.5145 - loss: 1.3765 - val_accuracy: 0.4593 - val_loss: 1.4944
# Epoch 3/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 238s 152ms/step - accuracy: 0.5937 - loss: 1.1792 - val_accuracy: 0.6522 - val_loss: 1.0060
# Epoch 4/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 237s 152ms/step - accuracy: 0.6510 - loss: 1.0260 - val_accuracy: 0.5530 - val_loss: 1.3013
# Epoch 5/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 226s 145ms/step - accuracy: 0.6957 - loss: 0.9100 - val_accuracy: 0.6924 - val_loss: 0.9172
# Epoch 6/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 232s 148ms/step - accuracy: 0.7223 - loss: 0.8300 - val_accuracy: 0.6872 - val_loss: 0.9177
# Epoch 7/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 240s 154ms/step - accuracy: 0.7544 - loss: 0.7436 - val_accuracy: 0.7074 - val_loss: 0.8989
# Epoch 8/30
# ...

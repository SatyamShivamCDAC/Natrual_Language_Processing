# %%
from tensorflow import keras
from keras.layers import Dense,Flatten,Input,Conv2D,MaxPool2D,Dropout
from keras.models import Sequential
from keras.utils import plot_model,to_categorical
from keras.datasets import cifar10
import cv2

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale = 1/255,zoom_range=0.2,horizontal_flip=True,vertical_flip=True)
test_datagen = ImageDataGenerator(rescale = 1/255,zoom_range=0.2,horizontal_flip=True,vertical_flip=True)

# %%
train = train_datagen.flow_from_directory(
    '../datasets/fruits/training_set',
    class_mode = 'binary',
    target_size = (64,64)
)
# Out:
# Found 13 images belonging to 2 classes.

# %%
train.filenames
# Out:
# ['apple\\1.jpg',
#  'apple\\2.jpeg',
#  'apple\\3.jpeg',
#  'apple\\4.jpeg',
#  'apple\\5.jpg',
#  'apple\\6.jpg',
#  'apple\\7.jpg',
#  'orange\\1.jpeg',
#  'orange\\2.jpg',
#  'orange\\3.jpeg',
#  'orange\\4.jpeg',
#  'orange\\5.jpg',
#  'orange\\6.jpg']

# %%
test = train_datagen.flow_from_directory(
    '../datasets/fruits/test_set',
    class_mode = 'binary',
    target_size = (64,64)
)
# Out:
# Found 6 images belonging to 2 classes.

# %% [markdown]
# <h1>Build the model</h1>

# %%
model = Sequential()

model.add(Input(shape = (64,64,3)))

model.add(Conv2D(filters = 16,kernel_size=(3,3),activation = 'relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 8,kernel_size = (3,3),activation = 'relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(32,activation = 'relu'))
model.add(Dense(1,activation = 'sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 62, 62, 16)          │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 31, 31, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 29, 29, 8)           │           1,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 14, 14, 8)           │               0 │
# ...

# %%
model.compile(loss = 'binary_crossentropy', optimizer = 'adam',metrics = ['accuracy'])

# %%
model.fit(train,validation_data = test,epochs = 10,batch_size = 1)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.4615 - loss: 0.6867 - val_accuracy: 0.5000 - val_loss: 0.6779
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.5385 - loss: 0.6812 - val_accuracy: 0.6667 - val_loss: 0.6610
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8462 - loss: 0.6500 - val_accuracy: 0.5000 - val_loss: 0.6515
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.7692 - loss: 0.6330 - val_accuracy: 0.8333 - val_loss: 0.5935
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.6923 - loss: 0.6311 - val_accuracy: 0.8333 - val_loss: 0.6041
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8462 - loss: 0.5910 - val_accuracy: 0.5000 - val_loss: 0.6167
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.6923 - loss: 0.5780 - val_accuracy: 0.8333 - val_loss: 0.5352
# Epoch 8/10
# ...

# %%
s1 = plt.imread('../datasets/fruits/sample1.jpg')
s2 = plt.imread('../datasets/fruits/sample2.jpg')

# %%
s1 = cv2.resize(s1,(64,64))

# %%
s1 = s1.reshape(1,64,64,3)
s1.shape
# Out:
# (1, 64, 64, 3)

# %%
plt.imshow(s1[0])

# %%
pred1 = 'Orange' if  model.predict(s1) == 1 else 'Apple'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step

# %%
s2 = cv2.resize(s2,(64,64))

# %%
s2 = s2.reshape(1,64,64,3)
s2.shape
# Out:
# (1, 64, 64, 3)

# %%
plt.imshow(s2[0])

# %%
pred2 = 'Orange' if  model.predict(s2) == 1 else 'Apple'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step

# %%
pred1,pred2
# Out:
# ('Orange', 'Apple')

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# !pip install opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-contrib-python in c:\users\dai\appdata\local\programs\python\python313\lib\site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\dai\appdata\local\programs\python\python313\lib\site-packages (from opencv-contrib-python) (2.2.6)

# %%
img1 = cv2.imread('../datasets/images/eiphel1.png')
img2 = cv2.imread('../datasets/images/eiphel2.png')

fig, ax = plt.subplots(1, 2, figsize=(16, 8))

ax[0].imshow(img1, cmap='gray')
ax[1].imshow(img2, cmap='gray')

# %%
#sift
sift = cv2.SIFT_create()

# %%
keypoints_1,descriptors_1 = sift.detectAndCompute(img1,None)
keypoints_2,descriptors_2 = sift.detectAndCompute(img2,None)


len(keypoints_1), len(keypoints_2)
# Out:
# (332, 404)

# %%
#feature matching
bf = cv2.BFMatcher(cv2.NORM_L1,crossCheck = True)

matches = bf.match(descriptors_1,descriptors_2)
matches = sorted(matches,key = lambda x : x.distance)

img3 = cv2.drawMatches(img1,keypoints_1,img2,keypoints_2,matches[:20],img2,flags = 2)
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1b0aa0739d0>, None)

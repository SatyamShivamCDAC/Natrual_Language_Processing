# %%
from textblob import TextBlob

# %%
word = 'Shivam'

# %%
blob = TextBlob(word)

# %%
blob.correct()
# Out:
# TextBlob("Hiram")

# %%
sent = 'It was a grate daj. When they plaeyd on the ground'

# %%
blob = TextBlob(sent)
blob.correct()
# Out:
# TextBlob("It was a grate day. When they played on the ground")

# %%
blob.word_counts
# Out:
# defaultdict(int,
#             {'it': 1,
#              'was': 1,
#              'a': 1,
#              'grate': 1,
#              'daj': 1,
#              'when': 1,
#              'they': 1,
#              'plaeyd': 1,
#              'on': 1,
#              'the': 1,
#              'ground': 1})

# %%
blob.pos_tags
# Out:
# [('It', 'PRP'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('grate', 'JJ'),
#  ('daj', 'NN'),
#  ('When', 'WRB'),
#  ('they', 'PRP'),
#  ('plaeyd', 'VBP'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('ground', 'NN')]

# %%
blob.tokenize()
# Out:
# WordList(['It', 'was', 'a', 'grate', 'daj', '.', 'When', 'they', 'plaeyd', 'on', 'the', 'ground'])

# %%
blob.sentences
# Out:
# [Sentence("It was a grate daj."), Sentence("When they plaeyd on the ground")]

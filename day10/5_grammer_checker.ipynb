# %%
# !pip install language-tool-python
# Out:
# Collecting language-tool-python
#   Downloading language_tool_python-3.1.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: requests in c:\users\dai\appdata\local\programs\python\python313\lib\site-packages (from language-tool-python) (2.32.5)
# Requirement already satisfied: tqdm in c:\users\dai\appdata\local\programs\python\python313\lib\site-packages (from language-tool-python) (4.67.1)
# Requirement already satisfied: packaging in c:\users\dai\appdata\local\programs\python\python313\lib\site-packages (from language-tool-python) (25.0)
# Requirement already satisfied: psutil in c:\users\dai\appdata\local\programs\python\python313\lib\site-packages (from language-tool-python) (7.1.0)
# Requirement already satisfied: toml in c:\users\dai\appdata\local\programs\python\python313\lib\site-packages (from language-tool-python) (0.10.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dai\appdata\local\programs\python\python313\lib\site-packages (from requests->language-tool-python) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dai\appdata\local\programs\python\python313\lib\site-packages (from requests->language-tool-python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dai\appdata\local\programs\python\python313\lib\site-packages (from requests->language-tool-python) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dai\appdata\local\programs\python\python313\lib\site-packages (from requests->language-tool-python) (2025.8.3)
# Requirement already satisfied: colorama in c:\users\dai\appdata\local\programs\python\python313\lib\site-packages (from tqdm->language-tool-python) (0.4.6)
# Downloading language_tool_python-3.1.0-py3-none-any.whl (50 kB)
# Installing collected packages: language-tool-python
# Successfully installed language-tool-python-3.1.0

# %%
import language_tool_python

# %%
#download the support language

my_tool = language_tool_python.LanguageTool('en-US')
# Out:
# Downloading LanguageTool latest: 100%|██████████████████████████████████████████████| 255M/255M [00:45<00:00, 5.59MB/s]

# %%
#define a sample text 
my_text = 'He Have collected documents. I is there.'
matches  = my_tool.check(my_text)
for m in matches:
    print(m)
# Out:
# Offset 3, length 4, Rule ID: HE_VERB_AGR
# Message: The pronoun ‘He’ is usually used with a third-person or a past tense verb.
# Suggestion: Has; Had
# He Have collected documents. I is there.
#    ^^^^
# Offset 31, length 2, Rule ID: PERS_PRONOUN_AGREEMENT
# Message: Did you mean “am” or “will be”?
# Suggestion: am; will be
# He Have collected documents. I is there.
#                                ^^

# %%
my_tool.correct(my_text)
# Out:
# 'He Has collected documents. I am there.'

# %%
# !pip install indic_transliteration
# Out:
# ...
#
#    -------- ------------------------------- 1/5 [roman]
#    ------------------------ --------------- 3/5 [typer]
#    ------------------------ --------------- 3/5 [typer]
#    ------------------------ --------------- 3/5 [typer]
#    -------------------------------- ------- 4/5 [indic_transliteration]
#    -------------------------------- ------- 4/5 [indic_transliteration]
#    -------------------------------- ------- 4/5 [indic_transliteration]
#    -------------------------------- ------- 4/5 [indic_transliteration]
#    -------------------------------- ------- 4/5 [indic_transliteration]
#    ---------------------------------------- 5/5 [indic_transliteration]
#
# ...

# %%
from indic_transliteration import sanscript
from indic_transliteration.sanscript import transliterate

# %%
text = 'Satyam'

# %%
ttext = print(transliterate(text,sanscript.ITRANS,sanscript.DEVANAGARI))
ttext
# Out:
# षत्यम्

# %%
ttext = print(transliterate(text,sanscript.ITRANS,sanscript.BENGALI))
ttext
# Out:
# ষত্যম্

# %%
ttext = print(transliterate(text,sanscript.ITRANS,sanscript.TAMIL))
ttext
# Out:
# ஷத்யம்

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 ttext = print(transliterate(text,sanscript.ITRANS,sanscript.GUJRATI))
#       2 ttext
#
# AttributeError: module 'indic_transliteration.sanscript' has no attribute 'GUJRATI'

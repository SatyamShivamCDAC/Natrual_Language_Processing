# %%
# !pip install gtts playsound

# %%
from gtts import gTTS
from playsound import playsound

# %%
tts = gTTS(text = 'Welcome to world of deep learning using python',lang  ='en')

# %%
#savubg the audio
tts.save('audio.mp3')
playsound('audio.mp3')
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipython-input-1369992178.py in <cell line: 0>()
#       1 #savubg the audio
#       2 tts.save('audio.mp3')
# ----> 3 playsound('audio.mp3')
#
# /usr/local/lib/python3.12/dist-packages/playsound.py in <lambda>(sound, block)
#     252         except:
#     253             logger.warning("playsound is relying on another python subprocess. Please use `pip install pygobject` if you want playsound to run more efficiently.")
# --> 254             playsound = lambda sound, block = True: _playsoundAnotherPython('/usr/bin/python3', sound, block, macOS = False)
#     255
#     256 del system
#
# /usr/local/lib/python3.12/dist-packages/playsound.py in _playsoundAnotherPython(otherPython, sound, block, macOS)
#     227     t.start()
#     228     if block:
# --> 229         t.join()
#     230
#     231 from platform import system
#
# ...

# %%
tts1 = gTTS(text = 'चिराग पीछे देख',lang  ='hi')
#savubg the audio
tts1.save('audio1.mp3')

# %%
tts2 = gTTS(text = 'पीछे क्या देख रहा हैं आगे देख ',lang  ='hi')
#savubg the audio
tts2.save('audio2.mp3')
